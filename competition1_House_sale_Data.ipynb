# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('sample_submission.csv')
df = pd.read_csv('test.csv')
df = pd.read_csv('train.csv')

# %%
# Basic Information
print(df.info())

print("First 5 rows")
print(df.head())

print("Missing values ")
print(df.isnull().sum)

print("Summary")
print(df.describe(include="all"))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# Check for null values in each column
print("Number of null values per column:")
print(df.isnull().sum())

# Remove rows with any null values
df_cleaned = df.dropna()

print("\nShape of the DataFrame after removing null values:")
print(df_cleaned.shape)
# Out:
# Number of null values per column:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64
#
# Shape of the DataFrame after removing null values:
# (0, 81)

# %%
df_cleaned_lotfrontage = df.dropna(subset=['LotFrontage'])

print("Shape of the DataFrame after removing rows with null values in LotFrontage:")
print(df_cleaned_lotfrontage.shape)

print("\nNumber of null values in LotFrontage after removal:")
print(df_cleaned_lotfrontage['LotFrontage'].isnull().sum())
# Out:
# Shape of the DataFrame after removing rows with null values in LotFrontage:
# (1201, 81)
#
# Number of null values in LotFrontage after removal:
# 0
